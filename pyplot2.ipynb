# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanishka3/zetz1/blob/main/pyplot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf9a5897-64d5-4a4a-bf75-09558fe864f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf9a5897-64d5-4a4a-bf75-09558fe864f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('NewspaperData.csv')
print(df)
df.head()

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2f6f6606aa2c> in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
import seaborn as sns
sns.distplot(df['daily'])
# Out:
# <ipython-input-8-60e927544913>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['daily'])
# <Axes: xlabel='daily', ylabel='Density'>

# %%
import statsmodels.formula.api as smf
model=smf.ols("sunday~daily",data=df).fit()

# %%
sns.regplot(x='daily',y='sunday',data=df)
# Out:
# <Axes: xlabel='daily', ylabel='sunday'>

# %%
rsq_hp=smf.ols('HP~WT+VOL+SP',data=cars).fit().rsquares
vif_hp=1/(1-rsq_hp)
rsq_wt=smf.ols('WT~HP+VOL+SP',data=cars).fit().rsquares
vif_wt=1/(1-rsq_wt)
rsq_vol=smf.ols('VOL~HP+WT+SP',data=cars).fit().rsquares
vif_vol=1/(1-rsq_vol)
rsq_hp=smf.ols('SP~HP+WT+VOL',data=cars).fit().rsquares
vif_hp=1/(1-rsq_hp)
d1={'Variables':['HP','WT','VOL','SP'],'VIF':[vif_hp,vif_wt,vif_vol,vif_hp]}
Vif_frame=pd.DataFrame(d1)
Vif_frame
